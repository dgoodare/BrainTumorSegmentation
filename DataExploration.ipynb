# %% [markdown]
# # The 4 modalities:
# * Flair
# * T1
# * T1CE
# * T2
#
# ![Flair](gifs/flair.gif "Flair")
# ![t1](gifs/t1.gif "t1")
# ![t1ce](gifs/t1ce.gif "t1ce")
# ![t2](gifs/t2.gif "t2")
# ![segmentation](gifs/segmentation.gif "segmentation")

# %%
from DataExploration import display_slice
display_slice(100)
